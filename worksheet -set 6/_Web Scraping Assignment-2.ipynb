# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\nirma\anaconda3\lib\site-packages (4.7.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\nirma\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\nirma\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\nirma\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio~=0.17 in c:\users\nirma\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\nirma\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in c:\users\nirma\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\nirma\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: idna in c:\users\nirma\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in c:\users\nirma\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\nirma\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: sortedcontainers in c:\users\nirma\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\nirma\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: pycparser in c:\users\nirma\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\nirma\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\nirma\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\nirma\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By

import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Q1: Write a python program to scrape data for “Data Analyst” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name, experience_required. You have to scrape first 10 jobs data

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url='https://www.naukri.com/'
driver.get(url)

# %%
driver.maximize_window()

# %%
designation = driver.find_element(By.CLASS_NAME,"suggestor-input")
designation.send_keys('Data Analyst')

# %%
location = driver.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input") # This XPath input

location.send_keys('Bangalore')

# %%
search=driver.find_element(By.CLASS_NAME,"qsbSubmit")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
# Scraping Job title from the given page

title_tags=driver.find_elements(By.XPATH,'//a[@class="title ellipsis"]')
for i in title_tags[0:10]:
    title=i.text
    job_title.append(title)


# Scraping Job Location from the given page

location_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft locWdth"]')
for i in location_tags[0:10]:
    location=i.text
    job_location.append(location)

# Scraping company name from the given page

company_tags=driver.find_elements(By.XPATH,"//a[@class='subTitle ellipsis fleft']")
for i in company_tags[0:10]:
    company=i.text
    company_name.append(company)

# Scraping Job Experience from the given page

experience_tags=driver.find_elements(By.XPATH,'//span[@class="ellipsis fleft expwdth"]')
for i in experience_tags[0:10]:
    exp=i.text
    experience_required.append(exp)

# %%
print(len(job_title),len(job_location),len(company_name),len(experience_required))
# Out:
# 10 10 10 10

# %%
import pandas as pd

df=pd.DataFrame({'Title':job_title,'Location':job_location,'Company_name':company_name,'Experience':experience_required})
df
# Out:
#                                                Title  \
# 0  Photon Hires Data Analyst, Night shift# Immedi...
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3                                       Data Analyst
# 4  Senior Business Analyst/Data Engineer - Python...
# 5         Data Analyst/Senior Analyst - R/SQL/Python
# 6            Manager / Senior Manager - Data Analyst
# 7  Assistant Manager/Manager - Data Analyst - Ana...
# 8                                       Data Analyst
# 9                  Data Analyst - SQL ETL/SSIS - KPO
#
#                                             Location             Company_name  \
# 0                       Bangalore/Bengaluru, Chennai                   Photon
# 1                                Bangalore/Bengaluru            Multi Recruit
# 2                       Hybrid - Bangalore/Bengaluru        Snom Ventures Llp
# 3       Bangalore/Bengaluru, Noida, Gurgaon/Gurugram                  Genpact
# 4                                Bangalore/Bengaluru         Huquo Consulting
# 5  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...  The Nikharv Consultancy
# 6  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...         Huquo Consulting
# 7                   Bangalore/Bengaluru, Delhi / NCR         Huquo Consulting
# 8                                Bangalore/Bengaluru                   Target
# 9                         Bangalore/Bengaluru, Noida         Huquo Consulting
#
#   Experience
# 0    1-3 Yrs
# 1    4-5 Yrs
# 2    1-3 Yrs
# 3    5-7 Yrs
# 4    3-6 Yrs
# 5    3-6 Yrs
# 6    2-7 Yrs
# 7   6-11 Yrs
# 8    2-4 Yrs
# 9    4-9 Yrs

# %% [markdown]
# Q2:Write a python program to scrape data for “Data Scientist” Job position in “Bangalore” location. You have to scrape the job-title, job-location, company_name. You have to scrape first 10 jobs data. This task will be done in following steps:

# %%
driver2=webdriver.Chrome('chromedriver.exe')
driver2.get('https://www.naukri.com/')

# %%
driver2.maximize_window()

# %%
search_jobs2=driver2.find_element(By.CLASS_NAME,'suggestor-input').send_keys("Data Analyst")

# %%
search_location2= driver2.find_element(By.XPATH,"/html/body/div[1]/div[6]/div/div/div[5]/div/div/div/input")
search_location2.send_keys('Bangalore')

# %%
search_button2= driver2.find_element("xpath",'/html/body/div[1]/div[6]/div/div/div[6]')
search_button2.click()

# %%
title_tags2=driver2.find_elements("xpath",'//a[@class="title ellipsis"]')
job_title2=[]
for i in title_tags2:
    job_title2.append(i.text)
    
loc_tags2=driver2.find_elements("xpath",'//span[@class="ellipsis fleft locWdth"]')
job_loc2=[]
for i in loc_tags2:
    job_loc2.append(i.text)
    
comp_tags2=driver2.find_elements("xpath",'//a[@class="subTitle ellipsis fleft"]')
comp_title2=[]
for i in comp_tags2:
    comp_title2.append(i.text)

# %%
print(len(job_title2),len(job_loc2),len(comp_title2))
# Out:
# 20 20 20

# %%
Data_Analyst_2=pd.DataFrame({'Job Title':job_title2,'Job Location':job_loc2,'Company Name':comp_title2})
Data_Analyst_2[0:10]
# Out:
#                                            Job Title  \
# 0  Photon Hires Data Analyst, Night shift# Immedi...
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3                                       Data Analyst
# 4  Senior Business Analyst/Data Engineer - Python...
# 5         Data Analyst/Senior Analyst - R/SQL/Python
# 6            Manager / Senior Manager - Data Analyst
# 7                              Business Data Analyst
# 8  Assistant Manager/Manager - Data Analyst - Ana...
# 9                                       Data Analyst
#
#                                         Job Location             Company Name
# 0                       Bangalore/Bengaluru, Chennai                   Photon
# 1                                Bangalore/Bengaluru            Multi Recruit
# 2                       Hybrid - Bangalore/Bengaluru        Snom Ventures Llp
# 3       Bangalore/Bengaluru, Noida, Gurgaon/Gurugram                  Genpact
# 4                                Bangalore/Bengaluru         Huquo Consulting
# 5  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...  The Nikharv Consultancy
# 6  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...         Huquo Consulting
# 7  Bangalore/Bengaluru, Hyderabad/Secunderabad, G...                   Acenet
# 8                   Bangalore/Bengaluru, Delhi / NCR         Huquo Consulting
# 9                                Bangalore/Bengaluru                   Target

# %% [markdown]
# Q3: In this question you have to scrape data using the filters available on the webpage as shown below:

# %%
driver3=webdriver.Chrome('chromedriver.exe')
driver3.get('https://www.naukri.com/')

# %%
search_jobs3=driver3.find_element(By.CLASS_NAME,'suggestor-input')
search_jobs3.send_keys("Data Analyst")

# %%
search_button3= driver3.find_element("xpath",'/html/body/div[1]/div[6]/div/div/div[6]')
search_button3.click()

# %%
location_filter = driver3.find_element('xpath','/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[4]/div[2]/div[1]/label/i')
location_filter.click()

# %%
salary_checkbox = driver3.find_element("xpath",'/html/body/div[1]/div[4]/div/div/section[1]/div[2]/div[5]/div[2]/div[4]/label/i')
salary_checkbox.click()

# %%
title_tags3=driver3.find_elements("xpath",'//a[@class="title ellipsis"]')
job_title3=[]
for i in title_tags3:
    job_title3.append(i.text)
    
loc_tags3=driver3.find_elements("xpath",'//span[@class="ellipsis fleft locWdth"]')
job_loc3=[]
for i in loc_tags3:
    job_loc3.append(i.text)  

sal_3=driver3.find_elements("xpath",'//span[@class="ellipsis fleft expwdth"]')
salary_3=[]
for i in sal_3:
    salary_3.append(i.text)

# %%
print(len(job_title2),len(job_loc2),len(comp_title2),len(salary_3))
# Out:
# 20 20 20 20

# %%
Data_Analyst_3=pd.DataFrame({'Job Title':job_title2,'Job Location':job_loc2,'Company Name':comp_title2, 'Salary':salary_3})
Data_Analyst_3[0:10]
# Out:
#                                            Job Title  \
# 0  Photon Hires Data Analyst, Night shift# Immedi...
# 1                                       Data Analyst
# 2                                       Data Analyst
# 3                                       Data Analyst
# 4  Senior Business Analyst/Data Engineer - Python...
# 5         Data Analyst/Senior Analyst - R/SQL/Python
# 6            Manager / Senior Manager - Data Analyst
# 7                              Business Data Analyst
# 8  Assistant Manager/Manager - Data Analyst - Ana...
# 9                                       Data Analyst
#
#                                         Job Location             Company Name  \
# 0                       Bangalore/Bengaluru, Chennai                   Photon
# 1                                Bangalore/Bengaluru            Multi Recruit
# 2                       Hybrid - Bangalore/Bengaluru        Snom Ventures Llp
# 3       Bangalore/Bengaluru, Noida, Gurgaon/Gurugram                  Genpact
# 4                                Bangalore/Bengaluru         Huquo Consulting
# 5  Bangalore/Bengaluru, Kolkata, Mumbai, Hyderaba...  The Nikharv Consultancy
# 6  Bangalore/Bengaluru, Mumbai, Hyderabad/Secunde...         Huquo Consulting
# 7  Bangalore/Bengaluru, Hyderabad/Secunderabad, G...                   Acenet
# 8                   Bangalore/Bengaluru, Delhi / NCR         Huquo Consulting
# 9                                Bangalore/Bengaluru                   Target
#
#      Salary
# 0   4-5 Yrs
# 1   1-3 Yrs
# 2   3-6 Yrs
# 3   3-6 Yrs
# 4   2-7 Yrs
# 5  7-10 Yrs
# 6   2-4 Yrs
# 7  7-12 Yrs
# 8   2-7 Yrs
# 9   3-6 Yrs

# %% [markdown]
# Q4: Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:

# %%
driver4=webdriver.Chrome('chromedriver.exe')
driver4.get('https://www.flipkart.com/')

# %%
popupclose = driver4.find_element("xpath","/html/body/div[2]/div/div/button")
popupclose.click()

# %%
search_product=driver4.find_element(By.CLASS_NAME,'_3704LK')
search_product.send_keys("Sunglasses")

# %%
search_button4= driver4.find_element(By.CLASS_NAME,'L0Z3Pu')
search_button4.click()

# %%
brand=driver4.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand[0:35]:
    brand_name.append(i.text)

product=driver4.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product[0:35]:
    product_desc.append(i.text)

price=driver4.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price[0:35]:
    product_price.append(i.text)

price_off=driver4.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount=[]
for i in price_off[0:35]:
    Discount.append(i.text)

# %%
print(len(brand_name),len(product_desc),len(product_price),len(Discount))
# Out:
# 35 35 35 35

# %%
product_1=pd.DataFrame({'Brand Name':brand_name,'Product Description':product_desc,'Price':product_price,'Discount':Discount})
product_1[:40]
# Out:
#            Brand Name                                Product Description  \
# 0      ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...
# 1                IRUS         UV Protection Retro Square Sunglasses (54)
# 2            Fastrack      UV Protection Wayfarer Sunglasses (Free Size)
# 3           Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 4              SUNBEE   UV Protection Rectangular Sunglasses (Free Size)
# 5          LIZA ANGEL  Riding Glasses, Night Vision Spectacle Sunglas...
# 6           Elligator                UV Protection Round Sunglasses (54)
# 7       VINCENT CHASE  by Lenskart Polarized, UV Protection Cat-eye S...
# 8              SUNBEE   UV Protection Rectangular Sunglasses (Free Size)
# 9          PHENOMENAL         UV Protection Retro Square Sunglasses (53)
# 10          Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...
# 11             Dervin      UV Protection Wayfarer Sunglasses (Free Size)
# 12           Fastrack  Gradient, UV Protection Wayfarer Sunglasses (F...
# 13               SRPM             UV Protection Wayfarer Sunglasses (50)
# 14          Elligator                UV Protection Round Sunglasses (53)
# 15     ROZZETTA CRAFT         UV Protection Round Sunglasses (Free Size)
# 16      VINCENT CHASE             UV Protection Wayfarer Sunglasses (59)
# 17               SRPM      Others Wayfarer, Retro Square Sunglasses (50)
# 18         LIZA ANGEL  Riding Glasses, UV Protection, Night Vision Sp...
# 19       Silver Kartz              UV Protection Aviator Sunglasses (88)
# 20             PIRASO              UV Protection Aviator Sunglasses (58)
# 21          New Specs   UV Protection Rectangular Sunglasses (Free Size)
# 22             PIRASO          UV Protection Rectangular Sunglasses (52)
# 23     RESIST EYEWEAR  Polarized, Riding Glasses, UV Protection Wayfa...
# 24             PIRASO           UV Protection Over-sized Sunglasses (60)
# 25           PROVOGUE  Polarized, UV Protection Rectangular Sunglasse...
# 26         LIZA ANGEL  UV Protection, Polarized Rectangular Sunglasse...
# 27        SKYZA INDIA   UV Protection Rectangular Sunglasses (Free Size)
# 28             PIRASO              UV Protection Aviator Sunglasses (54)
# 29               SRPM  Night Vision, UV Protection Round Sunglasses (54)
# 30             PIRASO           UV Protection Clubmaster Sunglasses (54)
# 31          CART2DEAL  Polarized, Riding Glasses Sports, Wrap-around ...
# 32     ROZZETTA CRAFT  UV Protection, Polarized, Mirrored Rectangular...
# 33  SHAAH COLLECTIONS              UV Protection Aviator Sunglasses (55)
# 34     ROZZETTA CRAFT      UV Protection Wayfarer Sunglasses (Free Size)
#
#      Price Discount
# 0     ₹447  77% off
# 1     ₹637  14% off
# 2     ₹619  38% off
# 3     ₹149  75% off
# 4     ₹129  87% off
# 5     ₹174  82% off
# 6     ₹229  90% off
# 7     ₹899  55% off
# 8     ₹129  87% off
# 9     ₹129  87% off
# 10    ₹129  87% off
# 11    ₹224  85% off
# 12    ₹579  35% off
# 13    ₹149  88% off
# 14    ₹149  85% off
# 15    ₹449  77% off
# 16    ₹599  70% off
# 17    ₹129  87% off
# 18    ₹129  74% off
# 19    ₹266  77% off
# 20    ₹274  89% off
# 21    ₹259  90% off
# 22    ₹182  88% off
# 23  ₹1,399  72% off
# 24    ₹270  89% off
# 25    ₹664  74% off
# 26    ₹129  87% off
# 27    ₹419  65% off
# 28    ₹244  84% off
# 29    ₹179  82% off
# 30    ₹257  83% off
# 31  ₹1,244  53% off
# 32    ₹497  75% off
# 33    ₹185  89% off
# 34    ₹649  74% off

# %%
page_2=driver4.find_element("xpath",'//a[@class="_1LKTO3"]')
page_2.click()

# %%
brand=driver4.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand[:37]:
    brand_name.append(i.text)

product=driver4.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product[:37]:
    product_desc.append(i.text)

price=driver4.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price[:37]:
    product_price.append(i.text)
    
price_off=driver4.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount=[]
for i in price_off[:37]:
    Discount.append(i.text)

# %%
print(len(brand_name),len(product_desc),len(product_price),len(Discount))
# Out:
# 37 37 37 37

# %%
product_2=pd.DataFrame({'Brand Name':brand_name[:37],'Product Description':product_desc[:37],'Price':product_price[:37],'Discount':Discount[:37]})

# %%
page_3=driver4.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand=driver4.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand[:36]:
    brand_name.append(i.text)
    
product=driver4.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product[:36]:
    product_desc.append(i.text)
    
price=driver4.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price[:36]:
    product_price.append(i.text)
    
price_off=driver4.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount=[]
for i in price_off[:36]:
    Discount.append(i.text)
    
product_3=pd.DataFrame({'Brand Name':brand_name[:36],'Product Description':product_desc[:36],'Price':product_price[:36],'Discount':Discount[:36]})

# %%
print(len(brand_name),len(product_desc),len(product_price),len(Discount))
# Out:
# 36 36 36 36

# %%
page_4=driver4.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand=driver4.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name=[]
for i in brand[:39]:
    brand_name.append(i.text)
    
product=driver4.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc=[]
for i in product[:39]:
    product_desc.append(i.text)
    
price=driver4.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price=[]
for i in price[:39]:
    product_price.append(i.text)
    
price_off=driver4.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount=[]
for i in price_off[:39]:
    Discount.append(i.text)
    
product_4=pd.DataFrame({'Brand Name':brand_name[:39],'Product Description':product_desc[:39],'Price':product_price[:39],'Discount':Discount[:39]})

# %%
print(len(brand_name),len(product_desc),len(product_price),len(Discount))
# Out:
# 39 39 39 39

# %%
product=pd.concat([product_1,product_2,product_3], ignore_index=True)

# %%
print(len(product))
# Out:
# 108

# %%
product[:100]
# Out:
#         Brand Name                                Product Description   Price  \
# 0   ROZZETTA CRAFT  UV Protection, Gradient Rectangular Sunglasses...    ₹447
# 1             IRUS         UV Protection Retro Square Sunglasses (54)    ₹637
# 2         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)    ₹619
# 3        Elligator  UV Protection Cat-eye, Retro Square, Oval, Rou...    ₹149
# 4           SUNBEE   UV Protection Rectangular Sunglasses (Free Size)    ₹129
# ..             ...                                                ...     ...
# 95  RESIST EYEWEAR  Polarized, Riding Glasses, UV Protection Wayfa...  ₹1,399
# 96          PIRASO          UV Protection Rectangular Sunglasses (52)    ₹182
# 97          PIRASO           UV Protection Over-sized Sunglasses (60)    ₹270
# 98      LIZA ANGEL  UV Protection, Polarized Rectangular Sunglasse...    ₹129
# 99     SKYZA INDIA   UV Protection Rectangular Sunglasses (Free Size)    ₹419
#
#    Discount
# 0   77% off
# 1   14% off
# 2   38% off
# 3   75% off
# 4   87% off
# ..      ...
# 95  72% off
# 96  88% off
# 97  89% off
# 98  87% off
# 99  65% off
#
# [100 rows x 4 columns]

# %% [markdown]
# Q5: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb/product%02reviews/itm4e5041ba101fd pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYZXSHRJ&market place=FLIPKART

# %%
driver5=webdriver.Chrome('chromedriver.exe')
driver5.get('https://www.flipkart.com/')

# %%
pop_close = driver5.find_element("xpath","/html/body/div[2]/div/div/button").click()

# %%
search_product2=driver5.find_element(By.CLASS_NAME,'_3704LK')
search_product2.send_keys("nokiaC2")

# %%
search_button5= driver5.find_element(By.CLASS_NAME,'L0Z3Pu')
search_button5.click()

# %%
driver5.get('https://www.flipkart.com/nokia-c-30-green-32-gb/p/itm47608c0b7481f?pid=MOBG7R5FR29FFHYF&lid=LSTMOBG7R5FR29FFHYF0K3LZ2&marketplace=FLIPKAR')

# %%
All_reviews=driver5.find_element("xpath",'//div[@class="_3UAT2v _16PBlm"]').click()

# %%
rating_tag1=driver5.find_elements("xpath",'//div[@class="_3LWZlK _1BLPMq"]')
rating1=[]
for i in rating_tag1[:6]:
    rating1.append(i.text)

review_sum1=driver5.find_elements("xpath",'//p[@class="_2-N8zT"]')
review1=[]
for i in review_sum1[:6]:
    review1.append(i.text)

review_full1=driver5.find_elements("xpath",'//div[@class="t-ZTKy"]')
full_review1=[]
for i in review_full1[:6]:
    full_review1.append(i.text.replace('\n',' , '))

# %%
print(len(rating1),len(review1),len(full_review1))
# Out:
# 6 6 6

# %%
Nokia_reviews1=pd.DataFrame({'Rating':rating1,'Review Summary':review1,'Full Review':full_review1})

# %%
Nokia_reviews1=pd.concat([Nokia_reviews1], ignore_index=True)
Nokia_reviews1[:6]
# Out:
#   Rating             Review Summary  \
# 0      5                  Brilliant
# 1      5                  Just wow!
# 2      5  Did not meet expectations
# 3      3                  Just wow!
# 4      5                       Fair
# 5      4        Best in the market!
#
#                                          Full Review
# 0  Buying a Nokia refreshed my memories of the go...
# 1                                       Good product
# 2                                      Not that good
# 3                                               Good
# 4                        Battery gets very heat fast
# 5                                               Good

# %% [markdown]
# Q6: Scrape data for first 100 sneakers you find when you visit flipkart.com and search for “sneakers” in the search field

# %%
driver6=webdriver.Chrome('chromedriver.exe')
driver6.get('https://www.flipkart.com/')

# %%
pop_close = driver6.find_element("xpath","/html/body/div[2]/div/div/button").click()

# %%
search_product6=driver6.find_element(By.CLASS_NAME,'_3704LK').send_keys("sneakers")

# %%
search_button6= driver6.find_element(By.CLASS_NAME,'L0Z3Pu').click()

# %%
brand6=driver6.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name6=[]
for i in brand6:
    brand_name6.append(i.text)
    
product6=driver6.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc6=[]
for i in product6:
    product_desc6.append(i.text)
    
price6=driver6.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price6=[]
for i in price6:
    product_price6.append(i.text)
    
price_off6=driver6.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount6=[]
for i in price_off6:
    Discount6.append(i.text)

# %%
print(len(product_desc6),len(product_price6),len(Discount6),len(brand_name6))

# %%
sneaker1=pd.DataFrame({'Brand Name':brand_name6[:30],'Product Description':product_desc6[:30], 'Product Price':product_price6[:30],'Discount':Discount6})

# %%
page_2=driver6.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %%
brand6=driver6.find_elements("xpath",'//div[@class="_2WkVRV"]')
brand_name6=[]
for i in brand6:
    brand_name6.append(i.text)
    
product6=driver6.find_elements("xpath",'//a[@class="IRpwTa"]')
product_desc6=[]
for i in product6:
    product_desc6.append(i.text)
    
price6=driver6.find_elements("xpath",'//div[@class="_30jeq3"]')
product_price6=[]
for i in price6:
    product_price6.append(i.text)
    
price_off6=driver6.find_elements("xpath",'//div[@class="_3Ay6Sb"]')
Discount6=[]
for i in price_off6:
    Discount6.append(i.text)
    
sneaker2=pd.DataFrame({'Brand Name':brand_name6[:30],'Product Description':product_desc6[:30], 'Product Price':product_price6[:30],'Discount':Discount6[

# %%
page_3=driver6.find_element("xpath",'//a[@class="_1LKTO3"]').click()

# %% [markdown]
# Q7: Go to webpage https://www.amazon.in/ Enter “Laptop” in the search field and then click the search icon. Then set CPU Type filter to “Intel Core i7” as shown in the below image:

# %%
driver = webdriver.Chrome(r"C:\Users\Sunny\Downloads\chromedriver_win32\chromedriver.exe")

# %%
url = 'https://www.amazon.in/'
driver.get(url)

# %%
search_product_name=driver.find_element(By.CLASS_NAME,'nav-input')
search_product_name.send_keys('Laptops')

# %%
Page=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
Page.click()

# %%
filter1=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[2]/li[14]/span/a/div')
filter1.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 filter1=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[2]/li[14]/span/a/div')
#       2 filter1.click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:444, in WebDriver.execute(self, driver_command, params)
#     442 response = self.command_executor.execute(driver_command, params)
#     443 if response:
# --> 444     self.error_handler.check_response(response)
#     445     response["value"] = self._unwrap_value(response.get("value", None))
#     446     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:249, in ErrorHandler.check_response(self, response)
#     247         alert_text = value["alert"].get("text")
#     248     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[1]/div[2]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[2]/li[14]/span/a/div"}
#   (Session info: chrome=109.0.5414.75)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00716643]
# 	(No symbol) [0x006ABE21]
# 	(No symbol) [0x005ADA9D]
# 	(No symbol) [0x005E1342]
# 	(No symbol) [0x005E147B]
# 	(No symbol) [0x00618DC2]
# 	(No symbol) [0x005FFDC4]
# 	(No symbol) [0x00616B09]
# 	(No symbol) [0x005FFB76]
# 	(No symbol) [0x005D49C1]
# 	(No symbol) [0x005D5E5D]
# 	GetHandleVerifier [0x0098A142+2497106]
# 	GetHandleVerifier [0x009B85D3+2686691]
# 	GetHandleVerifier [0x009BBB9C+2700460]
# 	GetHandleVerifier [0x007C3B10+635936]
# 	(No symbol) [0x006B4A1F]
# 	(No symbol) [0x006BA418]
# 	(No symbol) [0x006BA505]
# 	(No symbol) [0x006C508B]
# 	BaseThreadInitThunk [0x75B87D69+25]
# 	RtlInitializeExceptionChain [0x7700BB9B+107]
# 	RtlClearBits [0x7700BB1F+191]

# %%
title1=[]
#scrapting all the tags brand names
lap=driver.find_elements(By.CLASS_NAME,"a-size-mini")

#displaying 10 tags extracted above into text 
for i in lap:
    title1.append(i.text)
title1[0:10]
# Out:
# ['Up to',
#  '36',
#  '% off',
#  'Ends in',
#  '02:54:50',
#  '02:54:49',
#  'Up to',
#  '77',
#  '% off',
#  'Deal of the Day']

# %%
price_laptop=[]
#scrapting all the tags brand names
lap_price=driver.find_elements(By.CLASS_NAME,"a-price-whole")

#displaying 10 tags extracted above into text 
for i in lap_price:
    price_laptop.append(i.text)
price_laptop[0:10]
# Out:
# []

# %%
import pandas as pd
df = pd.DataFrame({'Laptop name':title1[0:10],'Price':price_laptop[0:10]})
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [73], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame({'Laptop name':title1[0:10],'Price':price_laptop[0:10]})
#       3 df
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:120, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     117 if verify_integrity:
#     118     # figure out the index, if necessary
#     119     if index is None:
# --> 120         index = _extract_index(arrays)
#     121     else:
#     122         index = ensure_index(index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:674, in _extract_index(data)
#     672 lengths = list(set(raw_lengths))
#     673 if len(lengths) > 1:
# --> 674     raise ValueError("All arrays must be of the same length")
#     676 if have_dicts:
#     677     raise ValueError(
#     678         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     679     )
#
# ValueError: All arrays must be of the same length
